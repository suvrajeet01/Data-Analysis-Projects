# %%
#! python3
from bs4 import BeautifulSoup
import requests
import re
import time
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

df= pd.DataFrame(data=None, index=None, columns=["url"])
def geturl(soup,df):
    data = soup.findAll('a',attrs={'class':'os_stat'});
    for i in data:
        index = len(df) + 1
        df.set_value(index, "url", i["href"])
    return df

#登陆世纪佳缘
login_url ='http://www.jiayuan.com/'
driver = webdriver.Chrome()
driver.get(login_url)
account = driver.find_element_by_xpath('//*[@id="hder_login_form_new"]/input[3]')
account.send_keys('13586720652')
password =driver.find_element_by_xpath('//*[@id="hder_login_form_new"]/input[4]')
password.send_keys('1993717')
account.send_keys(Keys.RETURN)
time.sleep(5)
search_url = "http://search.jiayuan.com/v2/"
driver.get(search_url)
try:
    for i in range(3): #删除重复条件
        time.sleep(1)
        driver.find_element_by_xpath("/html/body/div[7]/div[1]/div[3]/div[1]/dl[2]/dd[1]/div[2]/span[2]").click()
except:
    driver.find_element_by_xpath("/html/body/div[7]/div[1]/div[3]/div[1]/dl[2]/dd[1]/div[2]/span[1]").click()
time.sleep(5)
driver.find_element_by_id("s_list").click()
time.sleep(5)
html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
soup=BeautifulSoup(html,'lxml')
final = geturl(soup,df)
final.to_csv('user_url.csv', encoding='utf-8')


go = True
page = 0 
while(go== True):
    driver.execute_script("document.evaluate('/html/body/div[7]/div[1]/div[3]/div[4]/div/ol/li[4]/a', document, null, XPathResult.FIRST_ORDERED_NODE_TYPE, null).singleNodeValue.click()")
    time.sleep(1)
    html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
    soup=BeautifulSoup(html,'lxml')
    final = geturl(soup,df).drop_duplicates().reindex()
    final.to_csv('user_url.csv', encoding='utf-8')
    print("翻到了第"+ str(page) + "页")
    page += 1
    print("已经抓取了"+ str(len(final))+ "位用户的信息")
    page += 1
# Out:
# 翻到了第0页
# 已经抓取了37位用户的信息
# 翻到了第2页
# 已经抓取了48位用户的信息
# 翻到了第4页
# 已经抓取了66位用户的信息
# 翻到了第6页
# 已经抓取了84位用户的信息
# 翻到了第8页
# 已经抓取了101位用户的信息
# 翻到了第10页
# 已经抓取了119位用户的信息
# 翻到了第12页
# 已经抓取了137位用户的信息
# 翻到了第14页
# 已经抓取了155位用户的信息
# 翻到了第16页
# 已经抓取了173位用户的信息
# 翻到了第18页
# 已经抓取了191位用户的信息
# 翻到了第20页
# 已经抓取了209位用户的信息
# 翻到了第22页
# 已经抓取了226位用户的信息
# 翻到了第24页
# 已经抓取了244位用户的信息
# 翻到了第26页
# 已经抓取了262位用户的信息
# 翻到了第28页
# 已经抓取了280位用户的信息
# 翻到了第30页
# 已经抓取了298位用户的信息
# 翻到了第32页
# 已经抓取了316位用户的信息
# 翻到了第34页
# 已经抓取了334位用户的信息
# 翻到了第36页
# 已经抓取了352位用户的信息
# 翻到了第38页
# 已经抓取了370位用户的信息
# 翻到了第40页
# 已经抓取了388位用户的信息
# 翻到了第42页
# 已经抓取了406位用户的信息
# 翻到了第44页
# 已经抓取了424位用户的信息
# 翻到了第46页
# 已经抓取了442位用户的信息
# 翻到了第48页
# 已经抓取了460位用户的信息
# 翻到了第50页
# 已经抓取了478位用户的信息
# 翻到了第52页
# 已经抓取了496位用户的信息
# 翻到了第54页
# 已经抓取了514位用户的信息
# 翻到了第56页
# 已经抓取了532位用户的信息
# 翻到了第58页
# 已经抓取了550位用户的信息
# 翻到了第60页
# 已经抓取了568位用户的信息
# 翻到了第62页
# 已经抓取了583位用户的信息
# 翻到了第64页
# 已经抓取了596位用户的信息
# 翻到了第66页
# 已经抓取了614位用户的信息
# 翻到了第68页
# 已经抓取了632位用户的信息
# 翻到了第70页
# 已经抓取了650位用户的信息
# 翻到了第72页
# 已经抓取了668位用户的信息
# 翻到了第74页
# 已经抓取了686位用户的信息
# 翻到了第76页
# 已经抓取了704位用户的信息
# 翻到了第78页
# 已经抓取了722位用户的信息
# 翻到了第80页
# 已经抓取了740位用户的信息
# 翻到了第82页
# 已经抓取了758位用户的信息
# 翻到了第84页
# 已经抓取了776位用户的信息
# 翻到了第86页
# 已经抓取了794位用户的信息
# 翻到了第88页
# 已经抓取了812位用户的信息
# 翻到了第90页
# 已经抓取了830位用户的信息
# 翻到了第92页
# 已经抓取了848位用户的信息
# 翻到了第94页
# 已经抓取了864位用户的信息
# 翻到了第96页
# 已经抓取了878位用户的信息
# 翻到了第98页
# 已经抓取了894位用户的信息
# 翻到了第100页
# 已经抓取了912位用户的信息
# 翻到了第102页
# 已经抓取了923位用户的信息
# 翻到了第104页
# 已经抓取了936位用户的信息
# 翻到了第106页
# 已经抓取了947位用户的信息
# 翻到了第108页
# 已经抓取了964位用户的信息
# 翻到了第110页
# 已经抓取了973位用户的信息
# 翻到了第112页
# 已经抓取了979位用户的信息
# 翻到了第114页
# 已经抓取了986位用户的信息
# 翻到了第116页
# 已经抓取了996位用户的信息
# 翻到了第118页
# 已经抓取了1006位用户的信息
# 翻到了第120页
# 已经抓取了1006位用户的信息
# 翻到了第122页
# 已经抓取了1016位用户的信息
# 翻到了第124页
# 已经抓取了1026位用户的信息
# 翻到了第126页
# 已经抓取了1036位用户的信息
# 翻到了第128页
# 已经抓取了1046位用户的信息
# 翻到了第130页
# 已经抓取了1057位用户的信息
# 翻到了第132页
# 已经抓取了1067位用户的信息
# 翻到了第134页
# 已经抓取了1076位用户的信息
# 翻到了第136页
# 已经抓取了1086位用户的信息
# 翻到了第138页
# 已经抓取了1096位用户的信息
# 翻到了第140页
# 已经抓取了1109位用户的信息
# 翻到了第142页
# 已经抓取了1121位用户的信息
# 翻到了第144页
# 已经抓取了1136位用户的信息
# 翻到了第146页
# 已经抓取了1152位用户的信息
# 翻到了第148页
# 已经抓取了1162位用户的信息
# 翻到了第150页
# 已经抓取了1172位用户的信息
# 翻到了第152页
# 已经抓取了1182位用户的信息
# 翻到了第154页
# 已经抓取了1192位用户的信息
# 翻到了第156页
# 已经抓取了1202位用户的信息
# 翻到了第158页
# 已经抓取了1212位用户的信息
# 翻到了第160页
# 已经抓取了1221位用户的信息
# 翻到了第162页
# 已经抓取了1229位用户的信息
# 翻到了第164页
# 已经抓取了1238位用户的信息
# 翻到了第166页
# 已经抓取了1248位用户的信息
# 翻到了第168页
# 已经抓取了1258位用户的信息
# 翻到了第170页
# 已经抓取了1268位用户的信息
# 翻到了第172页
# 已经抓取了1278位用户的信息
# 翻到了第174页
# 已经抓取了1288位用户的信息
# 翻到了第176页
# 已经抓取了1303位用户的信息
# 翻到了第178页
# 已经抓取了1314位用户的信息
# 翻到了第180页
# 已经抓取了1324位用户的信息
# 翻到了第182页
# 已经抓取了1335位用户的信息
# 翻到了第184页
# 已经抓取了1345位用户的信息
# 翻到了第186页
# 已经抓取了1355位用户的信息
# 翻到了第188页
# 已经抓取了1365位用户的信息
# 翻到了第190页
# 已经抓取了1375位用户的信息
# 翻到了第192页
# 已经抓取了1385位用户的信息
# 翻到了第194页
# 已经抓取了1395位用户的信息
# 翻到了第196页
# 已经抓取了1408位用户的信息
# 翻到了第198页
# 已经抓取了1410位用户的信息
# 翻到了第200页
# 已经抓取了1410位用户的信息
# 翻到了第202页
# 已经抓取了1413位用户的信息
# 翻到了第204页
# 已经抓取了1413位用户的信息
# 翻到了第206页
# 已经抓取了1413位用户的信息
# 翻到了第208页
# 已经抓取了1413位用户的信息
# 翻到了第210页
# 已经抓取了1413位用户的信息
# 翻到了第212页
# 已经抓取了1413位用户的信息
# 翻到了第214页
# 已经抓取了1413位用户的信息
# 翻到了第216页
# 已经抓取了1413位用户的信息
# 翻到了第218页
# 已经抓取了1413位用户的信息
# 翻到了第220页
# 已经抓取了1413位用户的信息
# 翻到了第222页
# 已经抓取了1413位用户的信息
# 翻到了第224页
# 已经抓取了1413位用户的信息
# 翻到了第226页
# 已经抓取了1422位用户的信息
# 翻到了第228页
# 已经抓取了1422位用户的信息
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ccadd71fdaea> in <module>()
#      49     driver.execute_script("document.evaluate('/html/body/div[7]/div[1]/div[3]/div[4]/div/ol/li[4]/a', document, null, XPathResult.FIRST_ORDERED_NODE_TYPE, null).singleNodeValue.click()")
#      50     time.sleep(1)
# ---> 51     html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
#      52     soup=BeautifulSoup(html,'lxml')
#      53     final = geturl(soup,df).drop_duplicates().reindex()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     489         return self.execute(command, {
#     490             'script': script,
# --> 491             'args': converted_args})['value']
#     492
#     493     def execute_async_script(self, script, *args):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     252
#     253         params = self._wrap_value(params)
# --> 254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
#     256             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     462         path = string.Template(command_info[1]).substitute(params)
#     463         url = '%s%s' % (self._url, path)
# --> 464         return self._request(command_info[0], url, body=data)
#     465
#     466     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     486             try:
#     487                 self._conn.request(method, parsed_url.path, body, headers)
# --> 488                 resp = self._conn.getresponse()
#     489             except (httplib.HTTPException, socket.error):
#     490                 self._conn.close()
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from bs4 import BeautifulSoup
import requests
import re
import time
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

df= pd.DataFrame(data=None, index=None, columns=["url"])
def geturl(soup,df):
    data = soup.findAll('a',attrs={'class':'os_stat'});
    for i in data:
        index = len(df)
        try:
            df.set_value(index, "url", i["href"])
        except:
            print (i)
            pass
    return df

#登陆世纪佳缘
login_url ='http://www.jiayuan.com/'
driver = webdriver.Chrome()
driver.get(login_url)
account = driver.find_element_by_xpath('//*[@id="hder_login_form_new"]/input[3]')
account.send_keys('13586720652')
password =driver.find_element_by_xpath('//*[@id="hder_login_form_new"]/input[4]')
password.send_keys('1993717')
account.send_keys(Keys.RETURN)
time.sleep(5)

go = True
page = 1
current_num = 0
while(go== True):
    search_url = "http://search.jiayuan.com/v2/index.php?key=&sex=f&stc=1:33,23:1&sn=default&sv=1&pt=163&ft=off&f=select&mt=d&p=" + str(page)
    driver.get(search_url)
    time.sleep(2)
    html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
    soup=BeautifulSoup(html,'lxml')
    final = geturl(soup,df).drop_duplicates().reindex()
    final.to_csv('user_url.csv', encoding='utf-8')
    print("翻到了第"+ str(page) + "页")
    print("已经抓取了"+ str(len(final))+ "位用户的信息")
    page += 1
# Out:
# 翻到了第1页
# 已经抓取了30位用户的信息
# 翻到了第2页
# 已经抓取了58位用户的信息
# 翻到了第3页
# 已经抓取了85位用户的信息
# 翻到了第4页
# 已经抓取了112位用户的信息
# 翻到了第5页
# 已经抓取了139位用户的信息
# 翻到了第6页
# 已经抓取了166位用户的信息
# 翻到了第7页
# 已经抓取了193位用户的信息
# 翻到了第8页
# 已经抓取了220位用户的信息
# 翻到了第9页
# 已经抓取了247位用户的信息
# 翻到了第10页
# 已经抓取了260位用户的信息
# 翻到了第11页
# 已经抓取了280位用户的信息
# 翻到了第12页
# 已经抓取了305位用户的信息
# 翻到了第13页
# 已经抓取了332位用户的信息
# 翻到了第14页
# 已经抓取了353位用户的信息
# 翻到了第15页
# 已经抓取了367位用户的信息
# 翻到了第16页
# 已经抓取了391位用户的信息
# 翻到了第17页
# 已经抓取了418位用户的信息
# 翻到了第18页
# 已经抓取了445位用户的信息
# 翻到了第19页
# 已经抓取了472位用户的信息
# 翻到了第20页
# 已经抓取了499位用户的信息
# 翻到了第21页
# 已经抓取了526位用户的信息
# 翻到了第22页
# 已经抓取了553位用户的信息
# 翻到了第23页
# 已经抓取了580位用户的信息
# 翻到了第24页
# 已经抓取了607位用户的信息
# 翻到了第25页
# 已经抓取了634位用户的信息
# 翻到了第26页
# 已经抓取了661位用户的信息
# 翻到了第27页
# 已经抓取了688位用户的信息
# 翻到了第28页
# 已经抓取了715位用户的信息
# 翻到了第29页
# 已经抓取了742位用户的信息
# 翻到了第30页
# 已经抓取了769位用户的信息
# 翻到了第31页
# 已经抓取了796位用户的信息
# 翻到了第32页
# 已经抓取了823位用户的信息
# 翻到了第33页
# 已经抓取了850位用户的信息
# 翻到了第34页
# 已经抓取了877位用户的信息
# 翻到了第35页
# 已经抓取了904位用户的信息
# 翻到了第36页
# 已经抓取了928位用户的信息
# 翻到了第37页
# 已经抓取了940位用户的信息
# 翻到了第38页
# 已经抓取了962位用户的信息
# 翻到了第39页
# 已经抓取了989位用户的信息
# 翻到了第40页
# 已经抓取了1016位用户的信息
# 翻到了第41页
# 已经抓取了1043位用户的信息
# 翻到了第42页
# 已经抓取了1070位用户的信息
# 翻到了第43页
# 已经抓取了1097位用户的信息
# 翻到了第44页
# 已经抓取了1124位用户的信息
# 翻到了第45页
# 已经抓取了1151位用户的信息
# 翻到了第46页
# 已经抓取了1178位用户的信息
# 翻到了第47页
# 已经抓取了1205位用户的信息
# 翻到了第48页
# 已经抓取了1232位用户的信息
# 翻到了第49页
# 已经抓取了1259位用户的信息
# 翻到了第50页
# 已经抓取了1286位用户的信息
# 翻到了第51页
# 已经抓取了1313位用户的信息
# 翻到了第52页
# 已经抓取了1340位用户的信息
# 翻到了第53页
# 已经抓取了1367位用户的信息
# 翻到了第54页
# 已经抓取了1394位用户的信息
# 翻到了第55页
# 已经抓取了1421位用户的信息
# 翻到了第56页
# 已经抓取了1448位用户的信息
# 翻到了第57页
# 已经抓取了1475位用户的信息
# 翻到了第58页
# 已经抓取了1502位用户的信息
# 翻到了第59页
# 已经抓取了1529位用户的信息
# 翻到了第60页
# 已经抓取了1550位用户的信息
# 翻到了第61页
# 已经抓取了1568位用户的信息
# 翻到了第62页
# 已经抓取了1587位用户的信息
# 翻到了第63页
# 已经抓取了1614位用户的信息
# 翻到了第64页
# 已经抓取了1641位用户的信息
# 翻到了第65页
# 已经抓取了1668位用户的信息
# 翻到了第66页
# 已经抓取了1695位用户的信息
# 翻到了第67页
# 已经抓取了1722位用户的信息
# 翻到了第68页
# 已经抓取了1749位用户的信息
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-5624b34286ee> in <module>()
#      36     html = driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
#      37     soup=BeautifulSoup(html,'lxml')
# ---> 38     final = geturl(soup,df).drop_duplicates().reindex()
#      39     final.to_csv('user_url.csv', encoding='utf-8')
#      40     print("翻到了第"+ str(page) + "页")
#
# <ipython-input-15-5624b34286ee> in geturl(soup, df)
#      13     for i in data:
#      14         index = len(df)
# ---> 15         df.set_value(index, "url", i["href"])
#      16     return df
#      17
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'href'
