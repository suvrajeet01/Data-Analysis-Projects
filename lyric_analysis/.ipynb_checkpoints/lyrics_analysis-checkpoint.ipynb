# %%
import pandas as pd
import numpy as np
import jieba

# %% [markdown]
# ```
# df = pd.read_csv('final.csv')
# df=df[["alblum",'author','content','titles']]
# df.columns = ['album', 'singer','lyrics','title']
# df.to_csv('final_df.csv',encoding='utf-8')
#
# data = pd.read_csv('final_df.csv')
# del data['Unnamed: 0']
# data.head()
# data.describe()
#
#
#
#
#
#
# ```

# %%
# Out:
#                 album singer  \
# 0               《爱程集》    王力宏
# 1  《第六届全球华语歌曲排行榜颁奖典礼》    王力宏
# 2            《Nature》    王力宏
# 3           《盖世英雄演唱会》    王力宏
# 4              《爱情攻略》    王力宏
#
#                                               lyrics  \
# 0  比你更好 - 王力宏 词：王力宏 曲：王力宏 如什么都可修补 孤单真可起诉 或者只得我欠回报...
# 1  Kiss Goodbye - 王力宏 词：王力宏 曲：王力宏 Baby不要再哭泣 这一幕多么...
# 2                                                NaN
# 3  不可能错过你 演唱：王力宏 有时候只需要一首歌就能 让我自在 忘掉要排队空气 湿答答店员很坏...
# 4  想爱　王力宏 就是这一夜 凝结了空气和时间 强烈感到你就在身边 我已明白那就是爱 沉溺幸福的...
#
#                                                title
# 0                                               比你更好
# 1  Kiss Goodbye                                  ...
# 2                                               银色的湖
# 3                                        不可能错过你 [现场]
# 4                                                 想爱

# %%
# Out:
#                            album singer  \
# count                        884    885
# unique                       183     40
# top     《Sony Music-Man 世界巡回演唱会》    周杰伦
# freq                          29    299
#
#                                                    lyrics title
# count                                                 831   885
# unique                                                778   794
# top     轨迹 作词：黄俊郎 作曲：周杰伦 演唱：周杰伦 歌手独白 怎么隐藏　我的悲伤 失去你的地方 ...    画沙
# freq                                                    3     6

# %%
with open('stop_words.txt',encoding="utf8") as f:
    stop_words = f.read().splitlines() #载入stopword字典

# %%
def jieba_lyric(item):
    word_list = ""
    after = ",".join(jieba.cut(item))
    new_list = after.split(",")
    for word in new_list:
        if word not in stop_words and len(word)>0:
            word_list += word
    return word_list #不返回唯一值

# %%
import re
def title(item):
    item = item.replace(",", "")
    return re.findall(r"[\w']+", item)[0]

# %% [markdown]
# ```
# def generate_df(singer_name,data):
#     df = data[data["singer"] == singer_name]
#     df = df[pd.notnull(df['lyrics'])]
#     unique_df = df.drop_duplicates(['lyrics'], keep='last')
#     unique_df = unique_df[unique_df["lyrics"] != "Sorry，该歌曲暂无歌词。"]
#     unique_df.head()
#     unique_df= unique_df.reset_index(drop=True)
#     unique_df["lyrics"] = unique_df["lyrics"].apply(jieba_lyric)
#     unique_df["title"] = unique_df["title"].apply(title)
#     unique_df = unique_df.drop_duplicates(['title'], keep='last')
#     return unique_df
# df_lee = generate_df("王力宏",data)
# df_jay = generate_df("周杰伦",data)
# df_lin = generate_df("林俊杰",data)
# df_pan = generate_df("潘玮柏",data)
# result = pd.concat([df_lee,df_jay,df_lin,df_pan])
# result.to_csv("alltogether.csv",encoding='utf-8',index=False)
# ```

# %%
df = pd.read_csv('alltogether.csv')
df = df[["album","singer","lyrics","title"]]
df.head()
# Out:
#        album singer                                             lyrics   title
# 0      《爱程集》    王力宏  比你更好     如什么都可修补 孤单真可起诉 或者只得我欠回报 谁想将恋爱当回报 别的手 ...    比你更好
# 1     《爱情攻略》    王力宏  想爱　 就是这一夜 凝结了空气和时间 强烈感到你就在身边 我已明白那就是爱 沉溺幸福的味道叫...      想爱
# 2     《公转自转》    王力宏  One of these days     我的脚很轻 走在台北 一个人 半夜的自己 空荡的...     ONE
# 3     《公转自转》    王力宏  Please come back to me    邬裕康   盏盏街灯後退 车里播放思念 ...  Please
# 4  《盖世英雄演唱会》    王力宏  Follow Me Live 词曲  你我之间距离不是 唯一的联系 你我之间还有一种 跳动的...  Follow

# %% [markdown]
# ```
# sum = 0
# for i in result["lyrics"]:
#     try:
#         sum = sum + len(i)
#     except:
#         pass
# ```

# %% [markdown]
# ## 歌曲分词

# %% [markdown]
# ## 情感分析

# %%
from bosonnlp import BosonNLP
nlp = BosonNLP('poLhxbbz.14796.eN6V1q5khY5k')

# %%
def sentiment(sentence):
    sentence = sentence[15:]
    return nlp.sentiment(sentence,model='weibo')

# %%
def analysis_emotion(df):
    df["sentiment"] = df["lyrics"].apply(sentiment)
    df["positive"] = [i[0][0] for i in df["sentiment"]]
    df["negative"] = [i[0][1] for i in df["sentiment"]]
    positive_score = 0
    negative_score = 0
    for i in df["sentiment"]:
        positive_score += i[0][0]
        negative_score += i[0][1]
    
    return df,positive_score,negative_score

# %% [markdown]
# ## 王力宏

# %%
df_lee = df[df["singer"] == "王力宏"]
df_lee, positive_score_1, nagetive_score_1 = analysis_emotion(df_lee)
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(positive_score_1, nagetive_score_1)
df_lee.sort_values("positive",ascending=False).head(20)
#df_lee.sort_values("negative",ascending=False).head(30)
# Out:
# 77.1678923337349 76.83210766626512
#                         album singer  \
# 49                     《畅爽开怀》    王力宏
# 80   《Sony Music-Man 世界巡回演唱会》    王力宏
# 138                    《火力全开》    王力宏
# 126             《16个夏天 电视原声带》    王力宏
# 48                   《永远的第一天》    王力宏
# 145      《大马 Music Man 纪念精选辑》    王力宏
# 110                    《改变自己》    王力宏
# 14   《Sony Music-Man 世界巡回演唱会》    王力宏
# 9                    《不可能错过你》    王力宏
# 22                      《好想你》    王力宏
# 62                      《好想你》    王力宏
# 116                   《十八般武艺》    王力宏
# 147                   《十八般武艺》    王力宏
# 124                   《十八般武艺》    王力宏
# 88                   《永远的第一天》    王力宏
# 102                    《改变自己》    王力宏
# 133                    《火力全开》    王力宏
# 72                    《情敌贝多芬》    王力宏
# 151        《2006韩剧超强情歌精选No.1》    王力宏
# 143                    《改变自己》    王力宏
#
#                                                 lyrics    title  \
# 49   畅爽开怀 崔惟楷 Andrew Bloch Ed Dunne Butch Walker Ce...     畅爽开怀
# 80   放开你的心  baby我爱你快乐永远来得及 so come on now and放开你的心 ...    放开你的心
# 138  依然爱你  一闪一闪亮晶晶 留下岁月的痕迹 我的世界的中心 依然还是你 一年一年又一年 飞逝...     依然爱你
# 126  爱你等于爱自己  淋我淋过的雨  吹你吹过的风 比风雨还亲密 两个人的影子  在同一个天地 ...  爱你等于爱自己
# 48   欢喜城 谢铭祜   There is a city 要什么都有 热情的地方 交通很拥挤 遇到...      欢喜城
# 145  另一个天堂 葛大为David K.     张靓颖 你取代 前一秒我生命的空白 问题忽然找到...    另一个天堂
Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(positive_score_2, nagetive_score_2)
df_jay.sort_values("negative",ascending=True).head(30)
#df_jay.sort_values("negative",ascending=False).head(30)
# Out:
# 79.83191082097741 98.16808917902253
#                      album singer  \
# 192               《哎呦，不错哦》    周杰伦
# 187                 《十二新作》    周杰伦
# 293                  《魔杰座》    周杰伦
# 162             《天台 电影原声带》    周杰伦
# 180  《The Era 2010 超时代演唱会》    周杰伦
# 287                 《十二新作》    周杰伦
# 296             《周杰伦的床边故事》    周杰伦
# 291             《周杰伦的床边故事》    周杰伦
# 329             《周杰伦的床边故事》    周杰伦
# 178             《天台 电影原声带》    周杰伦
# 279             《周杰伦的床边故事》    周杰伦
# 266               《十一月的萧邦》    周杰伦
# 268              《周杰伦同名专辑》    周杰伦
# 271               《十一月的萧邦》    周杰伦
# 172               《哎呦，不错哦》    周杰伦
# 264                  《七里香》    周杰伦
# 315          《婚礼歌手 幸福情歌精选》    周杰伦
# 222                  《七里香》    周杰伦
# 308                  《我很忙》    周杰伦
# 229                  《惊叹号》    周杰伦
# 176                 《十二新作》    周杰伦
# 191               《哎呦，不错哦》    周杰伦
# 295          《婚礼歌手 幸福情歌精选》    周杰伦
# 261                《依然范特西》    周杰伦
# 159             《天台 电影原声带》    周杰伦
# 168              《情歌对唱大集合》    周杰伦
# 219                  《魔杰座》    周杰伦
# 290                  《七里香》    周杰伦
# 319                 《星座圣典》    周杰伦
# 216                  《叶惠美》    周杰伦
#
#                                                 lyrics    title  \
# 192  我要夏天 词曲 杨瑞代 别怕晒的黑 看起来很健康 泳池旁的妹 笑起来很阳光 对你Say个He...     我要夏天
# 187  梦想启动 林义杰    Come on go go go让梦重新启动 不同的汗水流着那不同的...     梦想启动
# 293  稻香     对这个世界如果你有太多的抱怨 跌倒了 就不敢继续往前走 为什么 人要这么的脆弱...       稻香
# 162  波爷 方文山    曾志伟OS睁大眼睛Show Time 杰伦小麦雪糕波爷中医  波爷中医 ...       波爷
# 180  你是我的OK绷 浪花兄弟 一个人的时候 在陌生的街头 抬头看着繁星夜垂的天空 I know ...  你是我的Ok绷
# 287  乌克丽丽     穿花衬衫要配上一把乌克丽丽 不然看起来会像流氓兄弟 穿西装要记得带个带个女...     乌克丽丽
# 296  前世情人 黄俊郎 Hathaway  松鼠陪着核桃 在庭院捉迷藏 葡萄躲进橡木桶 酿出时光 ...     前世情人
# 291  床边故事 方文山   从前从前有只猫头鹰 牠站在屋顶 屋顶后面一遍森林 森林很安静 安静的钢...     床边故事
# 329  告白气球 方文山   塞纳河畔 左岸的咖啡 我手一杯 品尝你的美 留下唇印的嘴 花店玫瑰 名...     告白气球
# 178  天台月光撒 你翦影我傻 知道自己配不上 但我 守著光 保护你那就像 捍卫这场美景一样 风吹切...    天台的月光
# 279  说走就走 方文山   伸出手 搭便车 唱着歌 弹着斑鸠 不远处沙漠 我们才刚刚经过 路两旁是...     说走就走
# 178  [[0.9394549926598084, 0.060545007340191616]]  0.939455  0.060545
# 279   [[0.9321088521115585, 0.06789114788844153]]  0.932109  0.067891
# 266    [[0.9195915290982638, 0.0804084709017362]]  0.919592  0.080408
# 268   [[0.9166797843575966, 0.08332021564240345]]  0.916680  0.083320
# 271      [[0.915596171778776, 0.084403828221224]]  0.915596  0.084404
# 172   [[0.9125493139003418, 0.08745068609965828]]  0.912549  0.087451
# 264   [[0.8980234684160153, 0.10197653158398469]]  0.898023  0.101977
# 315   [[0.8957875286965664, 0.10421247130343357]]  0.895788  0.104212
# 222   [[0.8915335356472626, 0.10846646435273742]]  0.891534  0.108466
# 308   [[0.8896323513307894, 0.11036764866921057]]  0.889632  0.110368
# 229    [[0.875201918700341, 0.12479808129965893]]  0.875202  0.124798
# 176    [[0.8731269303423724, 0.1268730696576276]]  0.873127  0.126873
# 191   [[0.8719280798007405, 0.12807192019925948]]  0.871928  0.128072
# 295   [[0.8615634255214202, 0.13843657447857982]]  0.861563  0.138437
# 261   [[0.8367539141221796, 0.16324608587782036]]  0.836754  0.163246
# 159   [[0.8298126545633122, 0.17018734543668776]]  0.829813  0.170187
# 168   [[0.8233631642759753, 0.17663683572402467]]  0.823363  0.176637
# 219   [[0.8228660311257665, 0.17713396887423355]]  0.822866  0.177134
# 290   [[0.8114568105074537, 0.18854318949254636]]  0.811457  0.188543
# 319    [[0.808484082298245, 0.19151591770175505]]  0.808484  0.191516
# 216   [[0.8029781080686333, 0.19702189193136663]]  0.802978  0.197022

# %% [markdown]
# ## 林俊杰

# %%
df_lin = df[df["singer"] == "林俊杰"]
df_lin,positive_score_3, nagetive_score_3 = analysis_emotion(df_lin)
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# F:\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(positive_score_3, nagetive_score_3)
df_lin.sort_values("negative",ascending=True).head(20)
df_lin.sort_values("negative",ascending=False).head(20)
# Out:
# 56.23126097560978 50.76873902439022
#               album singer                                             lyrics  \
# 400            《西界》    林俊杰  大男人小女孩     不是我的错 我们都听过 完美的时候 要更多 吵架时候说的太多 有时候的...
# 344           《乐行者》    林俊杰  压力 张思尔   它偷偷摸摸 混进了人类群中 话没有多说 打开了门的锁 我们的生活 忙得我们...
# 386       《编号89757》    林俊杰  木乃伊 林秋离简胜   你说要我 死了这颗心 最好永远 存放在埃及 像木乃伊 保持着神秘 敲...
# 367            《西界》    林俊杰  无聊 林秋离   没事做就会无聊 没有地方动手动脚 没事做就会无聊 没有地方动手动脚 闷到就...
# 392           《乐行者》    林俊杰  会有那么一天 张思尔   一九四三 世界大战 阿嬷年轻的时候 爷爷爱他那么多 他们感情很深 ...
# 403      《她说 概念自选辑》    林俊杰  我很想爱他 何启弘    天空 下起雨了 他撑的伞 在你身边陪着 可是 我不快乐 因为看见 ...
# 431  《乌鸦嘴妙女郎 电视原声带》    林俊杰    不潮不用花钱 林怡凤RAPJJ  Hey greedydont fret What yo...
# 356            《曹操》    林俊杰  Now That Shes Gone  Girl you know i miss you s...
# 359           《乐行者》    林俊杰  会读书  灯 不能熄灭 熬过今夜 就能从书中逃回到 这个世界 我 我不明白 这个年代 怎么还...
# 452     爱的歌   [[0.9647464265463013, 0.03525357345369872]]  0.964746  0.035254
# 514    限量发行  [[0.9585737753125295, 0.041426224687470516]]  0.958574  0.041426
# 538    反转地球  [[0.9433123950067748, 0.056687604993225275]]  0.943312  0.056688
# 479     次世代  [[0.9431633797581891, 0.056836620241810853]]  0.943163  0.056837
# 449    Good   [[0.9425676091397137, 0.05743239086028634]]  0.942568  0.057432
# 444     爱不离   [[0.9282926204267207, 0.07170737957327931]]  0.928293  0.071707
# 466    跟我走吧   [[0.9178476310017616, 0.08215236899823837]]  0.917848  0.082152
# 490    完美故事   [[0.9177066206237178, 0.08229337937628221]]  0.917707  0.082293
# 528     How   [[0.9150126763511959, 0.08498732364880415]]  0.915013  0.084987
# 532    快乐崇拜   [[0.9137594242801628, 0.08624057571983725]]  0.913759  0.086241
# 459     Pan   [[0.9043961908728425, 0.09560380912715749]]  0.904396  0.095604
# 450  我不识广东话    [[0.8976343047206139, 0.1023656952793861]]  0.897634  0.102366
# 504    Kiss   [[0.8894514356217553, 0.11054856437824463]]  0.889451  0.110549
# 456    说到做到   [[0.8816636150245548, 0.11833638497544523]]  0.881664  0.118336
# 523      谢谢   [[0.8750430893698482, 0.12495691063015181]]  0.875043  0.124957
# 458      给力   [[0.8601225881684027, 0.13987741183159735]]  0.860123  0.139877
# 501      小丑    [[0.8557884810401464, 0.1442115189598536]]  0.855788  0.144212

# %%
#单词分析
def word_analysis(df):
    word_list ={}
    for i in df["lyrics"]:
        lyric_list = []
        after = ",".join(jieba.cut(i))
        lyric_list = after.split(",")
        for word in lyric_list:
            if word not in stop_words and len(word)>0:
                if word not in word_list:
                    word_list[word] = 1
                else:
                    word_list[word] += 1

    count = [(word,word_list[word]) for word in word_list]
    count.sort(key=lambda x: x[1],reverse=True)
    return count
#('\u3000', 167) 中文全角空格

# %%
jay_count = word_analysis(df_jay)

# %%
def find_season(count_list):
    season = [0,0,0,0]
    for i in count_list:
        if i[0].find("春") >=0:
            print (i)
            season[0] += i[1]
        if i[0].find("夏")>=0:
            print (i)
            season[1] += i[1]
        if i[0].find("秋")>=0:
            print (i)
            season[2] += i[1]
        if i[0].find("冬")>=0:
            print (i)
            season[3] += i[1]
    return season

# %%
find_season(word_analysis(df_pan))
# Out:
# ('秋冬', 3)
# ('秋冬', 3)
# ('春夏', 3)
# ('春夏', 3)
# ('青春', 1)
# ('夏娃', 1)
# ('夏天', 1)
# ('春风', 1)
# [5, 5, 3, 3]

# %%
def find_his(count_list):
    season = [0,0,0,0]
    for i in count_list:
        if i[0].find("你") >=0:
            print (i)
            season[0] += i[1]
        if i[0].find("我")>=0:
            print (i)
            season[1] += i[1]
        if i[0].find("他")>=0:
            print (i)
            season[2] += i[1]
        if i[0].find("她")>=0:
            print (i)
            season[3] += i[1]
    return season

# %%
len(word_analysis(df_pan))
# Out:
# 5384

# %%
def count_total(count_list):
    total = 0
    for i in count_list:
        total += i[1]
    return total

# %%
count_total(word_analysis(df_lin))
# Out:
# 33277

# %%
def love(count_list):
    season = 0
    for i in count_list:
        if i[0].find("爱") >=0:
            season += i[1]
    return season

# %%
love(word_analysis(df_pan))
# Out:
# 601
