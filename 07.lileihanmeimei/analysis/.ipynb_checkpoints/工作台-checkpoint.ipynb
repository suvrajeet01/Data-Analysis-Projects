# %%
from bs4 import BeautifulSoup
import requests
import re
import time
import pandas as pd

# %%
text = "[]"
print (change_to_num(text))
# Out:
# None

# %%
def change_to_num(text):
    if len(text)>2:
        text = text[2:-3]
        return int(text)
    else:
        return None

# %%
df.head(10)
# Out:
#   用户序号   评分                                        个人主页   看过        想看  \
# 0    0  1.0  https://www.douban.com/people/yejiajunlove  352    ['1部']
# 1    1  3.0     https://www.douban.com/people/155553736    7        []
# 2    2  5.0     https://www.douban.com/people/160036365    1        []
# 3    3  4.0     https://www.douban.com/people/132407945   19   ['14部']
# 4    4  5.0     https://www.douban.com/people/162605587    1        []
# 5    5  NaN      https://www.douban.com/people/61621619   29    ['2部']
# 6    6  NaN     https://www.douban.com/people/139251537    1        []
# 7    7  1.0    https://www.douban.com/people/kuso99tt99  628   ['83部']
# 8    8  4.0     https://www.douban.com/people/146389417    2        []
# 9    9  3.0      https://www.douban.com/people/60592207  732  ['361部']
#
#          注册日期
# 0  2013-11-03
# 1  2016-12-26
# 2  2017-04-08
# 3  2015-08-03
# 4  2017-06-16
# 5  2012-05-23
# 6  2015-12-20
# 7  2009-07-12
# 8  2016-05-28
# 9  2012-04-20

# %%
df.to_csv('lileiandhanmeimei.csv', encoding='utf-8')

# %%
#df["看过"] = df["看过"].apply(change_to_num)
df["想看"] = df["想看"].apply(change_to_num)
df.head(10)
# Out:
#   用户序号   评分                                        个人主页   看过     想看  \
# 0    0  1.0  https://www.douban.com/people/yejiajunlove  352    1.0
# 1    1  3.0     https://www.douban.com/people/155553736    7    NaN
# 2    2  5.0     https://www.douban.com/people/160036365    1    NaN
# 3    3  4.0     https://www.douban.com/people/132407945   19   14.0
# 4    4  5.0     https://www.douban.com/people/162605587    1    NaN
# 5    5  NaN      https://www.douban.com/people/61621619   29    2.0
# 6    6  NaN     https://www.douban.com/people/139251537    1    NaN
# 7    7  1.0    https://www.douban.com/people/kuso99tt99  628   83.0
# 8    8  4.0     https://www.douban.com/people/146389417    2    NaN
# 9    9  3.0      https://www.douban.com/people/60592207  732  361.0
#
#          注册日期
# 0  2013-11-03
# 1  2016-12-26
# 2  2017-04-08
# 3  2015-08-03
# 4  2017-06-16
# 5  2012-05-23
# 6  2015-12-20
# 7  2009-07-12
# 8  2016-05-28
# 9  2012-04-20

# %%
df = pd.DataFrame.from_csv("addwatch.csv")
df.head(10)
for i in range(len(df)):
    df.set_value(i, "用户姓名", i)
df.columns = ['用户序号', '评分','个人主页','看过','想看','注册日期']
df.head(10)
# Out:
#   用户序号   评分                                        个人主页        看过        想看  \
# 0    0  1.0  https://www.douban.com/people/yejiajunlove  ['352部']    ['1部']
# 1    1  3.0     https://www.douban.com/people/155553736    ['7部']        []
# 2    2  5.0     https://www.douban.com/people/160036365    ['1部']        []
# 3    3  4.0     https://www.douban.com/people/132407945   ['19部']   ['14部']
# 4    4  5.0     https://www.douban.com/people/162605587    ['1部']        []
# 5    5  NaN      https://www.douban.com/people/61621619   ['29部']    ['2部']
# 6    6  NaN     https://www.douban.com/people/139251537    ['1部']        []
# 7    7  1.0    https://www.douban.com/people/kuso99tt99  ['628部']   ['83部']
# 8    8  4.0     https://www.douban.com/people/146389417    ['2部']        []
# 9    9  3.0      https://www.douban.com/people/60592207  ['732部']  ['361部']
#
#          注册日期
# 0  2013-11-03
# 1  2016-12-26
# 2  2017-04-08
# 3  2015-08-03
# 4  2017-06-16
# 5  2012-05-23
# 6  2015-12-20
# ...

# %%
dataframe = pd.DataFrame.from_csv("result.csv")
dataframe.head(10)
# Out:
#         用户姓名 评分情况                                        个人主页
# 0     麻蛋吖蛋巨蛋   很差  https://www.douban.com/people/yejiajunlove
# 1        雪中笑   还行     https://www.douban.com/people/155553736
# 2     贝克街的手心   力荐     https://www.douban.com/people/160036365
# 3        Leo   推荐     https://www.douban.com/people/132407945
# 4         新月   力荐     https://www.douban.com/people/162605587
# 5         凌人  NaN      https://www.douban.com/people/61621619
# 6         坤少  NaN     https://www.douban.com/people/139251537
# 7       電波玖爺   很差    https://www.douban.com/people/kuso99tt99
# 8  琉璃目月华人199   推荐     https://www.douban.com/people/146389417
# 9      在路上的他   还行      https://www.douban.com/people/60592207

# %%
dataframe["评分情况"] = dataframe["评分情况"].map({'很差': 1, '较差': 3,'还行':3,'推荐':4,"力荐":5})
dataframe
# Out:
#                  用户姓名  评分情况                                        个人主页
# 0              麻蛋吖蛋巨蛋   1.0  https://www.douban.com/people/yejiajunlove
# 1                 雪中笑   3.0     https://www.douban.com/people/155553736
# 2              贝克街的手心   5.0     https://www.douban.com/people/160036365
# 3                 Leo   4.0     https://www.douban.com/people/132407945
# 4                  新月   5.0     https://www.douban.com/people/162605587
# 5                  凌人   NaN      https://www.douban.com/people/61621619
# 6                  坤少   NaN     https://www.douban.com/people/139251537
# 7                電波玖爺   1.0    https://www.douban.com/people/kuso99tt99
# 8           琉璃目月华人199   4.0     https://www.douban.com/people/146389417
# 9               在路上的他   3.0      https://www.douban.com/people/60592207
# 10               是耶非耶   3.0     https://www.douban.com/people/155382204
# 11           Victor.L   4.0     https://www.douban.com/people/155724879
# ...

# %%
dataframe.to_csv("sample.csv",encoding='utf-8')

# %%
from bs4 import BeautifulSoup
import requests
import re
import time
import pandas as pd

#爬取个人电影页面
dataframe = pd.DataFrame.from_csv("sample.csv")

cookies = {}
raw_cookies = input("enter the cookies：")
#raw_cookies='ll="108289"; bid=4a89RwhDSCc; __utmt=1; __utma=30149280.2125343414.1497989209.1497989209.1498000258.2; __utmb=30149280.2.10.1498000258; __utmc=30149280; __utmz=30149280.1497989209.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); _ga=GA1.2.2125343414.1497989209; _gid=GA1.2.230149405.1498000349; _gat_UA-7019765-1=1; ue="clarkyu1993@outlook.com"; dbcl2="162795734:uwDhinrc7Ag"'

for line in raw_cookies.split(';'):
    key,value=line.split('=',1)#1代表只分一次，得到两个数据
    cookies[key[1:]]=value

dataframe["已经看过的电影"] = ''
dataframe["想看的电影"] = ''
dataframe["注册日期"] = ''

def find_movie(soup):
    a = soup.find_all("h2")
    text =""
    for item in a:
        text = text + str(item)
    pattern1 = re.compile('target.+>(\d+\S+)看过',re.S)
    pattern2 = re.compile('target.+>(\d+\S+)想看',re.S)
    num_movies1 = re.findall(pattern1,text)
    num_movies2 = re.findall(pattern2,text)
    return num_movies1,num_movies2

def register(soup):
    date_str = str(soup.find_all('div', class_="pl"))
    pattern = re.compile('<br/> (\S+)加入',re.S)
    date = re.findall(pattern,date_str)[0]
    return date
    
for i in range(2):
    url = dataframe["个人主页"][i]
    print("开始读取" + str(url))
    r= requests.get(url,cookies=cookies)
    soup = BeautifulSoup(r.content,"html.parser")
    num_movies1,num_movies2 = find_movie(soup) #观影数量
    date = register(soup) #注册时间
    
    dataframe.set_value(i, "已经看过的电影", num_movies1)
    dataframe.set_value(i, "想看的电影", num_movies2)
    dataframe.set_value(i, "注册日期",  date)
    
    print("结束，下一个")
    dataframe.to_csv('addwatch.csv', encoding='utf-8')
# Out:
# enter the cookies：bid=BIhpOOoK4n8; ll="108257"; __yadk_uid=zfb719wfDBUh8ONcpizL1DOV1JwsZTMm; ct=y; ps=y; _ga=GA1.2.512264618.1493254793; _gid=GA1.2.145269785.1498009165; _vwo_uuid_v2=0C3604E2647369A3E86811187785CBF6|60941d0bf77dbec57d7cc9a78bfc5c9f; _pk_ref.100001.8cb4=%5B%22%22%2C%22%22%2C1498041077%2C%22https%3A%2F%2Faccounts.douban.com%2Flogin%3Falias%3Dc.yu.4%2540warwick.ac.uk%26redir%3Dhttps%253A%252F%252Fwww.douban.com%252Fpeople%252F162795734%252F%26source%3DNone%26error%3D1012%22%5D; _pk_id.100001.8cb4=ca83e17ec25e8769.1493259013.37.1498042078.1498035021.; _pk_ses.100001.8cb4=*; push_noty_num=0; push_doumail_num=0; __utma=30149280.512264618.1493254793.1498008547.1498035003.50; __utmb=30149280.14.10.1498035003; __utmc=30149280; __utmz=30149280.1497999128.47.28.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmv=30149280.3906; ap=1; ue="yuchijing@126.com"; dbcl2="39068167:oLFx3IM7rSM"
# 开始读取https://www.douban.com/people/yejiajunlove

# %%
a = soup.find_all("h2")
text =""
for item in a:
    text = text + str(item)
pattern1 = re.compile('target.+>(\d+\S+)看过',re.S)
pattern2 = re.compile('target.+>(\d+\S+)想看',re.S)
num_movies1 = re.findall(pattern1,text)
num_movies2 = re.findall(pattern2,text)
num_movies2
# Out:
# []

# %%
def register(soup):
    date_str = str(soup.find_all('div', class_="pl"))
    pattern = re.compile('<br/>.+(.........\d)加入',re.S)
    date = re.findall(pattern,date_str)[0]
    return date

cookies = {}
raw_cookies = input("enter the cookies：")
#raw_cookies='ll="108289"; bid=4a89RwhDSCc; __utmt=1; __utma=30149280.2125343414.1497989209.1497989209.1498000258.2; __utmb=30149280.2.10.1498000258; __utmc=30149280; __utmz=30149280.1497989209.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); _ga=GA1.2.2125343414.1497989209; _gid=GA1.2.230149405.1498000349; _gat_UA-7019765-1=1; ue="clarkyu1993@outlook.com"; dbcl2="162795734:uwDhinrc7Ag"'

for line in raw_cookies.split(';'):
    key,value=line.split('=',1)#1代表只分一次，得到两个数据
    cookies[key[1:]]=value
url = 'https://www.douban.com/people/160036365'
r= requests.get(url,cookies=cookies)
soup = BeautifulSoup(r.content,"html.parser")
#date = register(soup) #注册时间
#date
# Out:
# enter the cookies：bid=BIhpOOoK4n8; ll="108257"; __yadk_uid=Cu1JCVGzmSek2Ri2gY94vNLLG4NRDsWy; ct=y; ps=y; _ga=GA1.2.512264618.1493254793; _gid=GA1.2.145269785.1498009165; _vwo_uuid_v2=0C3604E2647369A3E86811187785CBF6|60941d0bf77dbec57d7cc9a78bfc5c9f; _pk_ref.100001.4cf6=%5B%22%22%2C%22%22%2C1498063806%2C%22https%3A%2F%2Faccounts.douban.com%2Flogin%3Fsource%3Dmovie%22%5D; __utma=30149280.512264618.1493254793.1498061465.1498063811.52; __utmb=30149280.0.10.1498063811; __utmc=30149280; __utmz=30149280.1497999128.47.28.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmv=30149280.3906; __utma=223695111.1038917632.1493254793.1498035025.1498063811.26; __utmb=223695111.0.10.1498063811; __utmc=223695111; __utmz=223695111.1498035025.25.17.utmcsr=douban.com|utmccn=(referral)|utmcmd=referral|utmcct=/search; push_noty_num=0; push_doumail_num=0; ap=1; _pk_id.100001.4cf6=40734adeb1718cc1.1493254793.24.1498063813.1498040639.; _pk_ses.100001.4cf6=*; ue="yuchijing@126.com"; dbc
# ...

# %%
date_str = str(soup.find_all('div', class_="pl"))
print(date_str)
pattern = re.compile('<br/>.+(.........\d)加入',re.S)
date = re.findall(pattern,date_str)
date
# Out:
# [<div class="pl">161206792 <br> 2017-05-09加入</br></div>, <div class="j edtext pl" id="edit_intro">
# <span id="intro_display">我不想说</span>
# <form action="/j/people/161206792/edit_intro" mothod="post" name="edit_intro" style="display: none;">
# <textarea name="intro">我不想说</textarea><br/>
# <input class="submit" id="intro_submit" type="submit" value="保存">
# <input class="cancel" id="intro_cancel" type="button" value="取消">
# </input></input></form>
# <span class="attn" id="intro_error" style="display: none;"></span>
# </div>]
# []

# %%
str(soup.find_all('div', class_="pl"))
date_str = str(soup.find_all('div', class_="pl"))
date_str
# Out:
# '[<div class="pl">160036365 <br/> 2017-04-08加入</div>, <div class="j edtext pl" id="edit_intro">\n<span id="intro_display"></span>\n<form action="/j/people/160036365/edit_intro" mothod="post" name="edit_intro" style="display: none;">\n<textarea name="intro"></textarea><br/>\n<input class="submit" id="intro_submit" type="submit" value="保存">\n<input class="cancel" id="intro_cancel" type="button" value="取消">\n</input></input></form>\n<span class="attn" id="intro_error" style="display: none;"></span>\n</div>]'

# %%
pattern = re.compile('<br/>.+(.........\d)加入',re.S)
date = re.findall(pattern,date_str)

# %%
date
# Out:
# ['2017-04-08']

# %%
soup.find_all('div', class_="pl")
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>
# 雪中笑
# </title>
# <meta content="format=html5; url=https://www.douban.com/people/155553736/" http-equiv="mobile-agent"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <link href="https://img3.doubanio.com/f/shire/94213e812acbb00123f685909b4768bb304d16f3/css/douban.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var _head_start = new Date();</script>
# <script src="https://img3.doubanio.com/f/shire/72ced6df41d4d158420cebdd254f9562942464e3/js/jquery.min.js" type="text/javascript"></script>
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# ...

# %%
date_str = str(soup.find_all('div', class_="pl"))
#pattern = re.compile('<br/> (\S+)加入',re.S)
date = re.findall(pattern,date_str)[0]
date
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-af367750924a> in <module>()
#       1 date_str = str(soup.find_all('div', class_="pl"))
#       2 #pattern = re.compile('<br/> (\S+)加入',re.S)
# ----> 3 date = re.findall(pattern,date_str)[0]
#       4 date
#
# IndexError: list index out of range
